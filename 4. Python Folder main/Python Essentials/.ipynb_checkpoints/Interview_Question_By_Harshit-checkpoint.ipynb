# %% [markdown]
# # Here is the complete text extracted from the images you provided, combined into a single list of 50 questions.
#
# #### Python Questions Without Built-in Functions
#
# 1. Reverse a string without using built-in functions
#
# 2. Find the maximum number in a list without using max()
#
# 3. Find the minimum number in a list without using min()
#
# 4. Calculate the length of a string without using len()
#
# 5. Calculate the sum of elements in a list without using sum()
#
# 6. Check if a number is prime without using built-in functions
#
# 7. Implement factorial of a number without using math.factorial()
#
# 8. Implement bubble sort without using sorted() or sort()
#
# Check if a string is palindrome without using reversed()
#
# Find the second largest element in a list without using max()
#
# Implement binary search without using built-in methods
#
# Merge two sorted lists without using built-in functions
#
# Implement matrix multiplication without using NumPy
#
# Find GCD of two numbers without using math.gcd()
#
# Implement power function without using pow()
#
# Convert a decimal number to binary without using bin()
#
# Convert a binary number to decimal without using int()
#
# Check if a number is an Armstrong number
#
# Implement string concatenation without using + operator
#
# Remove duplicates from a list without using set()
#
# Count occurrences of each element in a list without using collections
#
# Find intersection of two lists without using set()
#
# Find union of two lists without using set()
#
# Find the mode of a list without using statistics module
#
# Rotate a list to the right by k positions
#
# Merge dictionaries without using built-in functions
#
# Implement linear search
#
# Implement selection sort
#
# Find common elements in three lists
#
# Find the missing number in a sequence
#
# Implement a queue using a list
#
# Implement a stack using a list
#
# Convert lowercase to uppercase without using upper()
#
# Convert uppercase to lowercase without using lower()
#
# Check if a number is a perfect square
#
# Check if a number is a Fibonacci number
#
# Implement insertion sort
#
# Reverse a list without using reverse()
#
# Find the first non-repeating character in a string
#
# Implement Caesar cipher encryption
#
# Implement a simple hash function
#
# Find the longest word in a string
#
# Implement a basic linked list
#
# Convert an integer to a string without using str()
#
# Convert a string to an integer without using int()
#
# Implement a function to find all subsets of a set
#
# Find the longest common prefix among strings
#
# Find the determinant of a matrix
#
# Implement a binary tree traversal
#
# Find the shortest path in a graph using BFS
